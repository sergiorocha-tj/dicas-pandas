# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiorocha-tj/dicas-pandas/blob/master/C%C3%B3digos2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/TA_PRECO_MEDICAMENTO.csv", encoding="ISO-8859-1", sep=";")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(10)
# Out:
#                                           SUBSTÂNCIA  ...              TARJA
# 0  SALICILATO DE FENILA;ÁCIDO SALICÍLICO;ÓXIDO DE...  ...         Tarja -(*)
# 1                   DIENOGESTE;VALERATO DE ESTRADIOL  ...  Tarja Vermelha(*)
# 2             HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  ...    Tarja  Vermelha
# 3             HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  ...    Tarja  Vermelha
# 4                                       MONTELUCASTE  ...    Tarja  Vermelha
# 5                                       MONTELUCASTE  ...    Tarja  Vermelha
# 6                                       MONTELUCASTE  ...    Tarja  Vermelha
# 7                                       MONTELUCASTE  ...    Tarja  Vermelha
# 8                                       MONTELUCASTE  ...    Tarja  Vermelha
# 9                                       MONTELUCASTE  ...    Tarja  Vermelha
#
# [10 rows x 40 columns]

# %%
df.columns
# Out:
# Index(['SUBSTÂNCIA', 'CNPJ', 'LABORATÓRIO', 'CÓDIGO GGREM', 'REGISTRO',
#        'EAN 1', 'EAN 2', 'EAN 3', 'PRODUTO', 'APRESENTAÇÃO',
#        'CLASSE TERAPÊUTICA', 'TIPO DE PRODUTO (STATUS DO PRODUTO)',
#        'REGIME DE PREÇO', 'PF Sem Impostos', 'PF 0%', 'PF 12%', 'PF 17%',
#        'PF 17% ALC', 'PF 17,5%', 'PF 17,5% ALC', 'PF 18%', 'PF 18% ALC',
#        'PF 20%', 'PMC 0%', 'PMC 12%', 'PMC 17%', 'PMC 17% ALC', 'PMC 17,5%',
#        'PMC 17,5% ALC', 'PMC 18%', 'PMC 18% ALC', 'PMC 20%',
#        'RESTRIÇÃO HOSPITALAR', 'CAP', 'CONFAZ 87', 'ICMS 0%',
#        'ANÁLISE RECURSAL',
#        'LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/COFINS)',
#        'COMERCIALIZAÇÃO 2020', 'TARJA'],
#       dtype='object')

# %%
df.tail()
# Out:
#                     SUBSTÂNCIA  ...              TARJA
# 26305  CLORIDRATO DE SEVELÂMER  ...  Tarja Vermelha(*)
# 26306          INSULINA HUMANA  ...  Tarja Vermelha(*)
# 26307          INSULINA HUMANA  ...    Tarja  Vermelha
# 26308      ISOCONAZOL;ABARELIX  ...    Tarja  Vermelha
# 26309       VALPROATO DE SÓDIO  ...         Tarja -(*)
#
# [5 rows x 40 columns]

# %%
df_filtro = df[df["COMERCIALIZAÇÃO 2020"] == "Não" ]

# %%
df_filtro.head
# Out:
# <bound method NDFrame.head of                                               SUBSTÂNCIA  ...              TARJA
# 0      SALICILATO DE FENILA;ÁCIDO SALICÍLICO;ÓXIDO DE...  ...         Tarja -(*)
# 1                       DIENOGESTE;VALERATO DE ESTRADIOL  ...  Tarja Vermelha(*)
# 2                 HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  ...    Tarja  Vermelha
# 3                 HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  ...    Tarja  Vermelha
# 10                                          MONTELUCASTE  ...  Tarja Vermelha(*)
# ...                                                  ...  ...                ...
# 26302                       UPADACITINIBE HEMI-HIDRATADO  ...  Tarja Vermelha(*)
# 26303                                        CABERGOLINA  ...    Tarja  Vermelha
# 26304                                        CABERGOLINA  ...    Tarja  Vermelha
# 26305                            CLORIDRATO DE SEVELÂMER  ...  Tarja Vermelha(*)
# ...

# %%
df_filtro2 = df[(df["COMERCIALIZAÇÃO 2020"] == "Não" ) & (df["RESTRIÇÃO HOSPITALAR"] == "Não" )]

# %%
df_filtro2.head
# Out:
# <bound method NDFrame.head of                                               SUBSTÂNCIA  ...              TARJA
# 0      SALICILATO DE FENILA;ÁCIDO SALICÍLICO;ÓXIDO DE...  ...         Tarja -(*)
# 1                       DIENOGESTE;VALERATO DE ESTRADIOL  ...  Tarja Vermelha(*)
# 2                 HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  ...    Tarja  Vermelha
# 3                 HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  ...    Tarja  Vermelha
# 10                                          MONTELUCASTE  ...  Tarja Vermelha(*)
# ...                                                  ...  ...                ...
# 26292                                LOPINAVIR;RITONAVIR  ...  Tarja Vermelha(*)
# 26293                                          RITONAVIR  ...  Tarja Vermelha(*)
# 26299                                          RITONAVIR  ...  Tarja Vermelha(*)
# 26302                       UPADACITINIBE HEMI-HIDRATADO  ...  Tarja Vermelha(*)
# ...

# %%
df_filtro2.reset_index()
# Out:
#        index  ...              TARJA
# 0          0  ...         Tarja -(*)
# 1          1  ...  Tarja Vermelha(*)
# 2          2  ...    Tarja  Vermelha
# 3          3  ...    Tarja  Vermelha
# 4         10  ...  Tarja Vermelha(*)
# ...      ...  ...                ...
# 10573  26292  ...  Tarja Vermelha(*)
# 10574  26293  ...  Tarja Vermelha(*)
# 10575  26299  ...  Tarja Vermelha(*)
# 10576  26302  ...  Tarja Vermelha(*)
# 10577  26308  ...    Tarja  Vermelha
#
# [10578 rows x 41 columns]

# %%
df_filtro2.loc[:,"PRODUTO"]
# Out:
# 0                             TALCO ALÍVIO
# 1                                CHARMELIE
# 2                               CO-RENITEC
# 3                               CO-RENITEC
# 10                               SINGULAIR
#                        ...
# 26292                              KALETRA
# 26293                              VIEKIRA
# 26299                               NORVIR
# 26302                               RINVOQ
# 26308    PRODUTO DE MEDICAMENTO PARA TESTE
# Name: PRODUTO, Length: 10578, dtype: object

# %%
df_filtro2.loc[:,["PRODUTO","APRESENTAÇÃO"]]
# Out:
#                                  PRODUTO                                       APRESENTAÇÃO
# 0                           TALCO ALÍVIO                                 TALQUEIRA C/ 100 G
# 1                              CHARMELIE  COM REV A + COM REV B + COM REV C + COM REV D ...
# 2                             CO-RENITEC               20 MG + 12,5 MG COM CT BL AL/AL X 30
# 3                             CO-RENITEC                 10 MG + 25 MG COM CT BL AL/AL X 30
# 10                             SINGULAIR          4 MG GRAN SOL CT 30 ENV AL/PLAS X 500 MG
# ...                                  ...                                                ...
# 26292                            KALETRA  (100,0 + 25,0) MG COM REV CT FR PLAS PEAD OPC ...
# 26293                            VIEKIRA  250 MG COM REV + 12,5 MG + 75 MG + 50 MG COM R...
# 26299                             NORVIR  100 MG PO SUS OR CT ENV AL PLAS PE/PET X 30 + ...
# ...

# %%
df_filtro2.isnull().sum()
# Out:
# SUBSTÂNCIA                                                   0
# CNPJ                                                         0
# LABORATÓRIO                                                  0
# CÓDIGO GGREM                                                 0
# REGISTRO                                                     0
# EAN 1                                                        0
# EAN 2                                                        0
# EAN 3                                                        0
# PRODUTO                                                      0
# APRESENTAÇÃO                                                 0
# CLASSE TERAPÊUTICA                                           0
# TIPO DE PRODUTO (STATUS DO PRODUTO)                          0
# REGIME DE PREÇO                                              0
# PF Sem Impostos                                              0
# PF 0%                                                        0
# ...

# %%
df_filtro2.notnull().sum()
# Out:
# SUBSTÂNCIA                                               10578
# CNPJ                                                     10578
# LABORATÓRIO                                              10578
# CÓDIGO GGREM                                             10578
# REGISTRO                                                 10578
# EAN 1                                                    10578
# EAN 2                                                    10578
# EAN 3                                                    10578
# PRODUTO                                                  10578
# APRESENTAÇÃO                                             10578
# CLASSE TERAPÊUTICA                                       10578
# TIPO DE PRODUTO (STATUS DO PRODUTO)                      10578
# REGIME DE PREÇO                                          10578
# PF Sem Impostos                                          10578
# PF 0%                                                    10578
# ...

# %%
df_filtro2.apply(lambda x: x.fillna(x.mean("PMC %)), axis=0)
# Out:
#   File "<ipython-input-56-3dcbd280e572>", line 1
#     df_filtro2.apply(lambda x: x.fillna(x.mean("PMC %)), axis=0)
#                                                                 ^
# SyntaxError: EOL while scanning string literal

# %%
df_filtro2.isnull()

# %%
df.head
